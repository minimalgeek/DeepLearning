# %%
import numpy as np
import pandas as pd
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_datareader as pdr
import itertools
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
import backtrader as bt
import pyfolio as pf

# %% [markdown]
# ### Parameters

# %%
ticker = 'CELG'
days=[5, 20]
return_days = 3
extreme = 3
test_date_start = datetime(2013,1,1)
test_date = test_date_start.strftime('%Y-%m-%d')
test_date_end = datetime(2017,1,1)
filename = '{}_{}_{}.h5py'.format(ticker, return_days, extreme)

# %%
aal = pdr.get_data_google(ticker, '2000-01-01', '2017-01-01')

# %%
aal.drop('Volume', axis=1, inplace=True)
aal.head()
# Out:
#             Open  High   Low  Close
# Date
# 2001-02-06  3.12  3.50  3.12   3.45
# 2001-02-07  3.41  3.45  3.16   3.35
# 2001-02-08  3.38  3.38  3.22   3.32
# 2001-02-09  3.31  3.34  3.21   3.30
# 2001-02-12  3.34  3.56  3.31   3.43

# %%
def _set_index_column_if_necessary(data: pd.DataFrame) -> pd.DataFrame:
    if 'Date' in data.columns:
        data.set_index('Date', inplace=True)
    return data

# %%
aal = _set_index_column_if_necessary(aal)
cols = aal.columns
aal.head()
# Out:
#             Open  High   Low  Close
# Date
# 2001-02-06  3.12  3.50  3.12   3.45
# 2001-02-07  3.41  3.45  3.16   3.35
# 2001-02-08  3.38  3.38  3.22   3.32
# 2001-02-09  3.31  3.34  3.21   3.30
# 2001-02-12  3.34  3.56  3.31   3.43

# %%
cols
# Out:
# Index(['Open', 'High', 'Low', 'Close'], dtype='object')

# %%
def feature(data, first_col, second_col):
    return data[first_col]/data[second_col]

# %%
def create_extra_columns(data, cols):
    pool = []
    for left, right in itertools.product(cols, cols):
        pair1 = left + right
        pair2 = right + left
        if left != right and pair1 not in pool and pair2 not in pool:
            aal[left + '/' + right] = feature(data, left, right)
            pool.append(pair1)

# %% [markdown]
# ### Rolling features

# %%
for col, day in itertools.product(cols, days):
    aal[col + ' ' + str(day) + ' MA'] = aal[col].rolling(day).mean()
    aal[col + ' ' + str(day) + ' max'] = aal[col].rolling(day).max()
    aal[col + ' ' + str(day) + ' min'] = aal[col].rolling(day).min()
aal.dropna(inplace=True)

# %%
aal.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Open 5 MA', 'Open 5 max', 'Open 5 min',
#        'Open 20 MA', 'Open 20 max', 'Open 20 min', 'High 5 MA', 'High 5 max',
#        'High 5 min', 'High 20 MA', 'High 20 max', 'High 20 min', 'Low 5 MA',
#        'Low 5 max', 'Low 5 min', 'Low 20 MA', 'Low 20 max', 'Low 20 min',
#        'Close 5 MA', 'Close 5 max', 'Close 5 min', 'Close 20 MA',
#        'Close 20 max', 'Close 20 min'],
#       dtype='object')

# %%
plain_features = list(filter(lambda col: '/' not in col, aal.columns))

# %%
create_extra_columns(aal, plain_features)

# %%
ret = 100*aal['Close'].pct_change(return_days).shift(-return_days)

# %%
# ret_dev = ret.rolling(10).std().fillna(1)

# ret_scaled = ret/ret_dev
# ret_scaled.head()

# %%
features_to_drop = list(filter(lambda col: '/' not in col, aal.columns))
aal.drop(features_to_drop, axis=1, inplace=True)

aal['Return'] = ret # ret_scaled
aal.head(10)
# Out:
#             Open/High  Open/Low  Open/Close  Open/Open 5 MA  Open/Open 5 max  \
# Date
# 2001-03-06   0.933140  1.000000    0.981651        0.986478         0.949704
# 2001-03-07   0.994083  1.021277    1.005988        1.024390         0.994083
# 2001-03-08   0.954286  1.080906    1.080906        1.010896         0.988166
# 2001-03-09   0.962382  1.040678    1.006557        0.938264         0.908284
# 2001-03-12   0.989899  1.126437    1.088889        0.923367         0.875000
# 2001-03-13   0.971731  1.049618    1.007326        0.889392         0.818452
# 2001-03-14   0.921429  1.011765    0.945055        0.878747         0.772455
# 2001-03-15   0.982143  1.018519    1.018519        0.975869         0.895765
# 2001-03-16   0.988848  1.141631    1.136752        0.972222         0.904762
# 2001-03-19   0.873134  1.012987    0.910506        0.894495         0.850909
#
#             Open/Open 5 min  Open/Open 20 MA  Open/Open 20 max  \
# Date
# 2001-03-06         1.000000         0.976723          0.909348
# 2001-03-07         1.046729         1.018645          0.951841
# 2001-03-08         1.040498         1.013657          0.946176
# 2001-03-09         1.000000         0.936118          0.869688
# 2001-03-12         1.000000         0.901564          0.832861
# 2001-03-13         1.000000         0.850998          0.779037
# 2001-03-14         1.000000         0.810302          0.732955
# 2001-03-15         1.065891         0.871632          0.781250
# 2001-03-16         1.031008         0.854756          0.786982
# 2001-03-19         1.000000         0.763708          0.692308
#
#             Open/Open 20 min  Open/High 5 MA    ...      \
# Date                                            ...
# 2001-03-06          1.146429        0.951957    ...
# 2001-03-07          1.200000        0.998217    ...
# 2001-03-08          1.192857        0.976608    ...
# 2001-03-09          1.096429        0.908822    ...
# 2001-03-12          1.050000        0.891990    ...
# 2001-03-13          1.000000        0.866415    ...
# 2001-03-14          1.000000        0.843689    ...
# 2001-03-15          1.065891        0.942426    ...
# 2001-03-16          1.031008        0.943932    ...
# 2001-03-19          1.000000        0.847826    ...
#
#             Close 5 max/Close 20 MA  Close 5 max/Close 20 max  \
# Date
# 2001-03-06                 1.008505                  0.962319
# 2001-03-07                 1.016279                  0.968116
# 2001-03-08                 1.020315                  0.968116
# 2001-03-09                 1.024540                  0.968116
# 2001-03-12                 1.034056                  0.968116
# 2001-03-13                 1.045383                  0.968116
# 2001-03-14                 0.976458                  0.895652
# 2001-03-15                 0.975376                  0.902367
# 2001-03-16                 0.887805                  0.812500
# 2001-03-19                 0.898470                  0.812500
#
#             Close 5 max/Close 20 min  Close 5 min/Close 20 MA  \
# Date
# 2001-03-06                  1.106667                 0.959903
# 2001-03-07                  1.113333                 0.961509
# 2001-03-08                  1.113333                 0.943944
# 2001-03-09                  1.113333                 0.935583
# 2001-03-12                  1.237037                 0.835913
# 2001-03-13                  1.237037                 0.845070
# 2001-03-14                  1.144444                 0.853215
# 2001-03-15                  1.129630                 0.863447
# 2001-03-16                  1.166667                 0.760976
# 2001-03-19                  1.166667                 0.770117
#
#             Close 5 min/Close 20 max  Close 5 min/Close 20 min  \
# Date
# 2001-03-06                  0.915942                  1.053333
# 2001-03-07                  0.915942                  1.053333
# 2001-03-08                  0.895652                  1.030000
# 2001-03-09                  0.884058                  1.016667
# 2001-03-12                  0.782609                  1.000000
# 2001-03-13                  0.782609                  1.000000
# 2001-03-14                  0.782609                  1.000000
# 2001-03-15                  0.798817                  1.000000
# 2001-03-16                  0.696429                  1.000000
# 2001-03-19                  0.696429                  1.000000
#
#             Close 20 MA/Close 20 max  Close 20 MA/Close 20 min  \
# Date
# 2001-03-06                  0.954203                  1.097333
# 2001-03-07                  0.952609                  1.095500
# 2001-03-08                  0.948841                  1.091167
# 2001-03-09                  0.944928                  1.086667
# 2001-03-12                  0.936232                  1.196296
# 2001-03-13                  0.926087                  1.183333
# 2001-03-14                  0.917246                  1.172037
# 2001-03-15                  0.925148                  1.158148
# 2001-03-16                  0.915179                  1.314103
# 2001-03-19                  0.904315                  1.298504
#
#             Close 20 max/Close 20 min     Return
# Date
# 2001-03-06                   1.150000  -6.727829
# 2001-03-07                   1.150000 -19.161677
# 2001-03-08                   1.150000 -11.650485
# 2001-03-09                   1.150000 -10.491803
# 2001-03-12                   1.277778   0.000000
# 2001-03-13                   1.277778 -14.285714
# 2001-03-14                   1.277778  -5.860806
# 2001-03-15                   1.251852  -7.037037
# 2001-03-16                   1.435897   4.273504
# 2001-03-19                   1.435897  -7.782101
#
# [10 rows x 379 columns]

# %%
len(aal.columns)
# Out:
# 379

# %%
list(aal.columns)[:5]
# Out:
# ['Open/High', 'Open/Low', 'Open/Close', 'Open/Open 5 MA', 'Open/Open 5 max']

# %% [markdown]
# # X/y spit

# %%
aal.dropna(inplace=True)
aal.replace([np.inf, -np.inf], 1, inplace=True)
X_data = aal.drop('Return', axis=1)
y_data = aal['Return']

# %%
X_data.head(2)
# Out:
#             Open/High  Open/Low  Open/Close  Open/Open 5 MA  Open/Open 5 max  \
# Date
# 2001-03-06   0.933140  1.000000    0.981651        0.986478         0.949704
# 2001-03-07   0.994083  1.021277    1.005988        1.024390         0.994083
#
#             Open/Open 5 min  Open/Open 20 MA  Open/Open 20 max  \
# Date
# 2001-03-06         1.000000         0.976723          0.909348
# 2001-03-07         1.046729         1.018645          0.951841
#
#             Open/Open 20 min  Open/High 5 MA            ...              \
# Date                                                    ...
# 2001-03-06          1.146429        0.951957            ...
# 2001-03-07          1.200000        0.998217            ...
#
#             Close 5 max/Close 5 min  Close 5 max/Close 20 MA  \
# Date
# 2001-03-06                 1.050633                 1.008505
# 2001-03-07                 1.056962                 1.016279
#
#             Close 5 max/Close 20 max  Close 5 max/Close 20 min  \
# Date
# 2001-03-06                  0.962319                  1.106667
# 2001-03-07                  0.968116                  1.113333
#
#             Close 5 min/Close 20 MA  Close 5 min/Close 20 max  \
# Date
# 2001-03-06                 0.959903                  0.915942
# 2001-03-07                 0.961509                  0.915942
#
#             Close 5 min/Close 20 min  Close 20 MA/Close 20 max  \
# Date
# 2001-03-06                  1.053333                  0.954203
# 2001-03-07                  1.053333                  0.952609
#
#             Close 20 MA/Close 20 min  Close 20 max/Close 20 min
# Date
# 2001-03-06                  1.097333                       1.15
# 2001-03-07                  1.095500                       1.15
#
# [2 rows x 378 columns]

# %%
y_data.head(2)
# Out:
# Date
# 2001-03-06    -6.727829
# 2001-03-07   -19.161677
# Name: Return, dtype: float64

# %%
def series_to_binarized_columns(y):
    pos = y > extreme
    neg = y < -extreme
    meds = (y > -extreme) & (y < extreme)
    y = np.array([neg, meds, pos]).T
    return y

# %%
X_train = X_data[:test_date]
X_test = X_data[test_date:]
y_train = y_data[:test_date]
y_test = y_data[test_date:]

# %%
y_train = series_to_binarized_columns(y_train)
y_test = series_to_binarized_columns(y_test)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
X_test_df = X_test.copy()
X_test = scaler.transform(X_test)
X_test_df = pd.DataFrame(X_test, columns=X_test_df.columns, index=X_test_df.index)

# %%
X_test_df.head(1)
# Out:
#             Open/High  Open/Low  Open/Close  Open/Open 5 MA  Open/Open 5 max  \
# Date
# 2013-01-02   0.305932 -0.697925   -0.469245        0.528119         0.750331
#
#             Open/Open 5 min  Open/Open 20 MA  Open/Open 20 max  \
# Date
# 2013-01-02        -0.022969        -0.031212          0.606253
#
#             Open/Open 20 min  Open/High 5 MA            ...              \
# Date                                                    ...
# 2013-01-02         -0.631687        0.835794            ...
#
#             Close 5 max/Close 5 min  Close 5 max/Close 20 MA  \
# Date
# 2013-01-02                -0.297708                -0.290138
#
#             Close 5 max/Close 20 max  Close 5 max/Close 20 min  \
# Date
# 2013-01-02                  0.476754                 -0.768619
#
#             Close 5 min/Close 20 MA  Close 5 min/Close 20 max  \
# Date
# 2013-01-02                -0.070545                  0.516564
#
#             Close 5 min/Close 20 min  Close 20 MA/Close 20 max  \
# Date
# 2013-01-02                 -0.754882                  0.984723
#
#             Close 20 MA/Close 20 min  Close 20 max/Close 20 min
# Date
# 2013-01-02                 -1.013084                   -0.99204
#
# [1 rows x 378 columns]

# %% [markdown]
# # KERAS

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, BatchNormalization, LSTM
from keras.optimizers import Adam, RMSprop
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import class_weight

# %%
def expand(X, axis=1):
    return np.expand_dims(X, axis=axis)

# %%
temp_y = np.argmax(y_train, axis=1)
cw = class_weight.compute_class_weight('balanced', np.unique(temp_y), temp_y)
cw
# Out:
# array([ 1.80839416,  0.57019563,  1.44250364])

# %%
input_shape = (1, 1, X_train.shape[1])
input_shape
# Out:
# (1, 1, 378)

# %%
def build_and_run():
    model = Sequential()
    model.add(LSTM(64, return_sequences=True, batch_input_shape=input_shape, stateful=True))
    model.add(Dropout(0.2))
    model.add(LSTM(64, return_sequences=False, stateful=True))
    model.add(Dropout(0.2))
    model.add(Dense(3, kernel_initializer='glorot_uniform'))
    model.add(Activation('softmax'))

    model.compile(optimizer=Adam(lr=0.001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    for i in range(30):
        print(f'Iteration {i}')
        model.fit(expand(X_train), y_train, class_weight=cw, batch_size=1, epochs=5, shuffle=False, verbose=2)
        model.reset_states()
    model.save(filename)
    return model

# %%
#model.fit(expand(X_train), y_train, class_weight=cw, batch_size=1, epochs=100, shuffle=False, verbose=2) # , validation_data=(expand(X_test), y_test)

# %%
try:
    model = load_model(filename)
except:
    model = build_and_run()

# %%
class ModelEvaluator:
    def __init__(self,
                 model):
        self.model = model

    def evaluate(self, X, y, ret):
        all_returns = []
        for c in [0.34 + x/50 for x in range(35)]:
            print('=================')
            print(f'Certainty is {c}')
            returns = self.calculate_returns(X, y, ret, c)
            cont = self.print_returns_distribution(returns)
            if not cont:
                break

    def calculate_returns(self, X, y, ret, certainty):
        predicted = self.model.predict(expand(X), batch_size=1)
        real_ups = y[:, 2]
        real_downs = y[:, 0]
        predicted_ups = (predicted[:, 2] > certainty)# & (np.argmax(predicted, axis=1) == 2)
        predicted_downs = (predicted[:, 0] > certainty)# & (np.argmax(predicted, axis=1) == 0)
        returns = np.append(ret[predicted_ups],
                            (-1 * ret[predicted_downs]))

        print('Real ups count: {}'.format(pd.value_counts(real_ups[predicted_ups])))
        print('Real downs count: {}'.format(pd.value_counts(real_downs[predicted_downs])))
        return returns

    def print_returns_distribution(self, returns):
        lose = np.sum(returns[returns < 0])
        win = np.sum(returns[returns > 0])
        if lose == 0 and win == 0:
            return False
        print('Negative returns:', str(lose))
        print('Positive returns:', str(win))
        print('Pos/Neg ratio:', str(win / (lose * -1)))
        print('Sum of returns:', str(np.sum(returns)))
        return True

# %%
evaluator = ModelEvaluator(model)
evaluator.evaluate(X_test, y_test, y_data[test_date:]) # [:988]
# Out:
# =================
# Certainty is 0.34
# Real ups count: False    152
# True      32
# dtype: int64
# Real downs count: False    21
# True      8
# dtype: int64
# Negative returns: -261.956469704
# Positive returns: 301.851074503
# Pos/Neg ratio: 1.15229478716
# Sum of returns: 39.8946047984
# =================
# Certainty is 0.36000000000000004
# Real ups count: False    142
# True      30
# dtype: int64
# Real downs count: False    17
# True      7
# dtype: int64
# Negative returns: -231.294404323
# Positive returns: 274.439379546
# Pos/Neg ratio: 1.18653704723
# Sum of returns: 43.1449752231
# =================
# Certainty is 0.38
# Real ups count: False    133
# True      26
# dtype: int64
# Real downs count: False    12
# True      7
# dtype: int64
# Negative returns: -198.322969719
# Positive returns: 244.656068261
# Pos/Neg ratio: 1.23362446926
# Sum of returns: 46.3330985421
# =================
# Certainty is 0.4
# Real ups count: False    120
# True      24
# dtype: int64
# Real downs count: False    9
# True     6
# dtype: int64
# Negative returns: -179.428039583
# Positive returns: 218.817895358
# Pos/Neg ratio: 1.21953010168
# Sum of returns: 39.3898557743
# =================
# Certainty is 0.42000000000000004
# Real ups count: False    117
# True      23
# dtype: int64
# Real downs count: False    8
# True     5
# dtype: int64
# Negative returns: -172.682436804
# Positive returns: 209.374501236
# Pos/Neg ratio: 1.21248289699
# Sum of returns: 36.6920644318
# =================
# Certainty is 0.44000000000000006
# Real ups count: False    116
# True      20
# dtype: int64
# Real downs count: False    8
# True     5
# dtype: int64
# Negative returns: -171.595646662
# Positive returns: 195.627469537
# Pos/Neg ratio: 1.14004914077
# Sum of returns: 24.031822875
# =================
# Certainty is 0.46
# Real ups count: False    103
# True      19
# dtype: int64
# Real downs count: False    8
# True     4
# dtype: int64
# Negative returns: -140.599462719
# Positive returns: 180.298435282
# Pos/Neg ratio: 1.28235508013
# Sum of returns: 39.6989725629
# =================
# Certainty is 0.48000000000000004
# Real ups count: False    99
# True     15
# dtype: int64
# Real downs count: False    8
# True     3
# dtype: int64
# Negative returns: -132.986712635
# Positive returns: 147.718603818
# Pos/Neg ratio: 1.11077716632
# Sum of returns: 14.7318911834
# =================
# Certainty is 0.5
# Real ups count: False    90
# True     14
# dtype: int64
# Real downs count: False    8
# True     2
# dtype: int64
# Negative returns: -121.891522701
# Positive returns: 138.278012888
# Pos/Neg ratio: 1.13443502734
# Sum of returns: 16.3864901864
# =================
# Certainty is 0.52
# Real ups count: False    86
# True     14
# dtype: int64
# Real downs count: False    8
# True     1
# dtype: int64
# Negative returns: -121.032665111
# Positive returns: 131.214038713
# Pos/Neg ratio: 1.08412087425
# Sum of returns: 10.1813736017
# =================
# Certainty is 0.54
# Real ups count: False    85
# True     13
# dtype: int64
# Real downs count: False    8
# True     1
# dtype: int64
# Negative returns: -121.032665111
# Positive returns: 125.434019525
# Pos/Neg ratio: 1.03636501278
# Sum of returns: 4.40135441384
# =================
# Certainty is 0.56
# Real ups count: False    79
# True     12
# dtype: int64
# Real downs count: False    7
# True     1
# dtype: int64
# Negative returns: -100.796926882
# Positive returns: 118.346761396
# Pos/Neg ratio: 1.17411080929
# Sum of returns: 17.5498345136
# =================
# Certainty is 0.5800000000000001
# Real ups count: False    75
# True     12
# dtype: int64
# Real downs count: False    7
# True     1
# dtype: int64
# Negative returns: -88.6226383896
# Positive returns: 117.764467566
# Pos/Neg ratio: 1.32883053028
# Sum of returns: 29.1418291761
# =================
# Certainty is 0.6000000000000001
# Real ups count: False    70
# True     10
# dtype: int64
# Real downs count: False    5
# True     1
# dtype: int64
# Negative returns: -82.1093792679
# Positive returns: 103.095808039
# Pos/Neg ratio: 1.25559112684
# Sum of returns: 20.9864287715
# =================
# Certainty is 0.6200000000000001
# Real ups count: False    67
# True     10
# dtype: int64
# Real downs count: False    5
# True     1
# dtype: int64
# Negative returns: -78.6241694761
# Positive returns: 100.230478527
# Pos/Neg ratio: 1.27480492569
# Sum of returns: 21.6063090505
# =================
# Certainty is 0.64
# Real ups count: False    62
# True     10
# dtype: int64
# Real downs count: False    5
# True     1
# dtype: int64
# Negative returns: -73.1820460094
# Positive returns: 97.5239791472
# Pos/Neg ratio: 1.33262165333
# Sum of returns: 24.3419331378
# =================
# Certainty is 0.66
# Real ups count: False    59
# True      7
# dtype: int64
# Real downs count: False    5
# True     1
# dtype: int64
# Negative returns: -71.4381984367
# Positive returns: 85.128118847
# Pos/Neg ratio: 1.1916330578
# Sum of returns: 13.6899204104
# =================
# Certainty is 0.68
# Real ups count: False    58
# True      7
# dtype: int64
# Real downs count: False    3
# True     1
# dtype: int64
# Negative returns: -67.9067561475
# Positive returns: 83.3879600364
# Pos/Neg ratio: 1.2279773732
# Sum of returns: 15.4812038889
# =================
# Certainty is 0.7
# Real ups count: False    51
# True      7
# dtype: int64
# Real downs count: False    3
# True     1
# dtype: int64
# Negative returns: -65.3282364851
# Positive returns: 78.4360184745
# Pos/Neg ratio: 1.20064496908
# Sum of returns: 13.1077819895
# =================
# Certainty is 0.72
# Real ups count: False    45
# True      7
# dtype: int64
# Real downs count: False    2
# dtype: int64
# Negative returns: -57.7163053124
# Positive returns: 69.5997212765
# Pos/Neg ratio: 1.20589356681
# Sum of returns: 11.8834159641
# =================
# Certainty is 0.74
# Real ups count: False    39
# True      6
# dtype: int64
# Real downs count: False    2
# dtype: int64
# Negative returns: -56.2626866233
# Positive returns: 61.8612286244
# Pos/Neg ratio: 1.09950719273
# Sum of returns: 5.59854200112
# =================
# Certainty is 0.76
# Real ups count: False    33
# True      4
# dtype: int64
# Real downs count: False    1
# dtype: int64
# Negative returns: -49.6713993837
# Positive returns: 48.6308994085
# Pos/Neg ratio: 0.979052332165
# Sum of returns: -1.0404999752
# =================
# Certainty is 0.78
# Real ups count: False    27
# True      4
# dtype: int64
# Real downs count: False    1
# dtype: int64
# Negative returns: -44.3833154158
# Positive returns: 44.8560107027
# Pos/Neg ratio: 1.0106502924
# Sum of returns: 0.472695286938
# =================
# Certainty is 0.8
# Real ups count: False    22
# True      3
# dtype: int64
# Real downs count: False    1
# dtype: int64
# Negative returns: -37.7179701609
# Positive returns: 35.1810510547
# Pos/Neg ratio: 0.932739776415
# Sum of returns: -2.5369191062
# =================
# Certainty is 0.8200000000000001
# Real ups count: False    18
# True      3
# dtype: int64
# Real downs count: False    1
# dtype: int64
# Negative returns: -36.7793502065
# Positive returns: 29.6812851622
# Pos/Neg ratio: 0.807009503853
# Sum of returns: -7.09806504431
# =================
# Certainty is 0.8400000000000001
# Real ups count: False    18
# True      3
# dtype: int64
# Real downs count: Series([], dtype: int64)
# Negative returns: -36.7793502065
# Positive returns: 27.9506306963
# Pos/Neg ratio: 0.759954445616
# Sum of returns: -8.8287195102
# =================
# Certainty is 0.8600000000000001
# Real ups count: False    16
# True      3
# dtype: int64
# Real downs count: Series([], dtype: int64)
# Negative returns: -31.8881537593
# Positive returns: 27.9506306963
# Pos/Neg ratio: 0.876520820469
# Sum of returns: -3.93752306297
# =================
# Certainty is 0.8800000000000001
# Real ups count: False    14
# True      2
# dtype: int64
# Real downs count: Series([], dtype: int64)
# Negative returns: -27.435686852
# Positive returns: 22.3514888726
# Pos/Neg ratio: 0.814686688661
# Sum of returns: -5.0841979794
# =================
# Certainty is 0.9000000000000001
# Real ups count: False    12
# True      2
# dtype: int64
# Real downs count: Series([], dtype: int64)
# Negative returns: -26.7424953222
# Positive returns: 21.6931499124
# Pos/Neg ratio: 0.811186452537
# Sum of returns: -5.0493454098
# =================
# Certainty is 0.9199999999999999
# Real ups count: False    9
# True     1
# dtype: int64
# Real downs count: Series([], dtype: int64)
# Negative returns: -20.0886275129
# Positive returns: 8.27232626645
# Pos/Neg ratio: 0.411791510453
# Sum of returns: -11.8163012464
# =================
# Certainty is 0.94
# Real ups count: False    6
# True     1
# dtype: int64
# Real downs count: Series([], dtype: int64)
# Negative returns: -8.58295715002
# Positive returns: 6.95666408206
# Pos/Neg ratio: 0.810520658611
# Sum of returns: -1.62629306796
# =================
# Certainty is 0.96
# Real ups count: False    4
# True     1
# dtype: int64
# Real downs count: Series([], dtype: int64)
# Negative returns: -8.06643829221
# Positive returns: 4.36669912779
# Pos/Neg ratio: 0.541341664017
# Sum of returns: -3.69973916442
# =================
# Certainty is 0.98
# Real ups count: False    2
# True     1
# dtype: int64
# Real downs count: Series([], dtype: int64)
# Negative returns: -1.42967542504
# Positive returns: 4.36669912779
# Pos/Neg ratio: 3.05432901155
# Sum of returns: 2.93702370276
# =================
# Certainty is 1.0
# Real ups count: Series([], dtype: int64)
# Real downs count: Series([], dtype: int64)

# %% [markdown]
# # Backtest

# %%
class TestStrategy(bt.Strategy):

    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        self.certainty = 0.4
        self.dataclose = self.datas[0].close
        self.orders = {}
        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')
            
    def entries_to_remove(entries, the_dict):
        for key in entries:
            if key in the_dict:
                del the_dict[key]

    def next(self):
        if not self.position:
            try:
                today = self.datas[0].datetime.date(0).isoformat()
                data_row = X_test_df.loc[today]
                prediction = model.predict(expand(expand(data_row,0),0))[0]
                def log_candles():
                    self.log('Current Open: {}, Close: {}'.format(self.data0.open[0],self.data0.close[0]))
                    self.log('Next Open: {}, Close: {}'.format(self.data0.open[1],self.data0.close[1]))
                
                if prediction[2] > self.certainty:
                    self.log(f'======> Predict long for {today}')
                    log_candles()
                    self.orders[len(self)] = self.buy(exectype=bt.Order.Market)
                elif prediction[0] > self.certainty:
                    self.log(f'======> Predict short for {today}')
                    log_candles()
                    self.orders[len(self)] = self.sell(exectype=bt.Order.Market)
            except Exception as e:
                self.log(e)
        
        old_entries = []
        for days, order_on_days in self.orders.items():
            if len(self) >= days + return_days:
                old_entries.append(days)
                if order_on_days.isbuy():
                    self.log('closing the long position')
                    self.sell(exectype=bt.Order.Market)
                else:
                    self.log('closing the short position')
                    self.buy(exectype=bt.Order.Market) # exectype=bt.Order.Close
        TestStrategy.entries_to_remove(old_entries, self.orders)

# %%
cerebro = bt.Cerebro()
cerebro.addstrategy(TestStrategy)

data = bt.feeds.YahooFinanceData(
    dataname=ticker,
    fromdate=test_date_start,
    todate=test_date_end,
    reverse=False)

cerebro.adddata(data)
cerebro.broker.setcash(100000.0)
cerebro.broker.setcommission(commission=0.001)
cerebro.broker.set_coc(True)
cerebro.addsizer(bt.sizers.PercentSizer, percents=50)

cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')

print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
results = cerebro.run()
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

strat = results[0]
pyfoliozer = strat.analyzers.getbyname('pyfolio')
returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()
# Out:
# Starting Portfolio Value: 100000.00
# 2013-04-24, Predict long for 2013-04-25
# 2013-04-25, BUY EXECUTED, 58.97
# 2013-04-29, closing the long position
# 2013-04-30, SELL EXECUTED, 59.03
# 2013-04-30, Predict long for 2013-05-01
# 2013-05-01, BUY EXECUTED, 58.33
# 2013-05-03, closing the long position
# 2013-05-06, SELL EXECUTED, 60.61
# 2013-05-07, Predict long for 2013-05-08
# 2013-05-08, BUY EXECUTED, 61.37
# 2013-05-10, closing the long position
# 2013-05-13, SELL EXECUTED, 64.83
# 2013-05-15, Predict long for 2013-05-16
# 2013-05-16, BUY EXECUTED, 61.74
# 2013-05-20, closing the long position
# 2013-05-21, SELL EXECUTED, 61.75
# 2013-05-21, Predict long for 2013-05-22
# 2013-05-22, BUY EXECUTED, 61.72
# 2013-05-24, closing the long position
# 2013-05-28, SELL EXECUTED, 62.29
# 2013-08-12, Predict long for 2013-08-13
# 2013-08-13, BUY EXECUTED, 68.82
# 2013-08-15, closing the long position
# 2013-08-16, SELL EXECUTED, 66.25
# 2013-08-16, Predict long for 2013-08-19
# 2013-08-19, BUY EXECUTED, 66.22
# 2013-08-21, closing the long position
# 2013-08-22, SELL EXECUTED, 68.96
# 2013-12-16, Predict long for 2013-12-17
# 2013-12-17, BUY EXECUTED, 80.39
# 2013-12-19, closing the long position
# 2013-12-20, SELL EXECUTED, 83.74
# 2013-12-23, Predict long for 2013-12-24
# 2013-12-24, BUY EXECUTED, 83.71
# 2013-12-27, closing the long position
# 2013-12-30, SELL EXECUTED, 84.49
# 2014-03-19, Predict long for 2014-03-20
# 2014-03-20, BUY EXECUTED, 75.00
# 2014-03-24, closing the long position
# 2014-03-25, SELL EXECUTED, 72.25
# 2014-03-25, Predict long for 2014-03-26
# 2014-03-26, BUY EXECUTED, 71.31
# 2014-03-28, closing the long position
# 2014-03-31, SELL EXECUTED, 69.80
# 2014-04-04, Predict long for 2014-04-07
# 2014-04-07, BUY EXECUTED, 69.58
# 2014-04-09, closing the long position
# 2014-04-10, SELL EXECUTED, 69.99
# 2014-04-10, Predict long for 2014-04-11
# 2014-04-11, BUY EXECUTED, 68.45
# 2014-04-15, closing the long position
# 2014-04-16, SELL EXECUTED, 70.93
# 2014-04-16, Predict long for 2014-04-17
# 2014-04-17, BUY EXECUTED, 70.75
# 2014-04-22, closing the long position
# 2014-04-23, SELL EXECUTED, 72.41
# 2014-12-30, Predict long for 2014-12-31
# 2014-12-31, BUY EXECUTED, 111.86
# 2015-01-05, closing the long position
# 2015-01-06, SELL EXECUTED, 110.51
# 2015-02-09, Predict short for 2015-02-10
# 2015-02-10, SELL EXECUTED, 120.16
# 2015-02-12, closing the short position
# 2015-02-13, BUY EXECUTED, 115.88
# 2015-03-24, Predict long for 2015-03-25
# 2015-03-25, BUY EXECUTED, 116.99
# 2015-03-27, closing the long position
# 2015-03-30, SELL EXECUTED, 120.02
# 2015-03-30, Predict long for 2015-03-31
# 2015-03-31, BUY EXECUTED, 115.28
# 2015-04-02, closing the long position
# 2015-04-06, SELL EXECUTED, 112.97
# 2015-04-06, Predict long for 2015-04-07
# 2015-04-07, BUY EXECUTED, 112.72
# 2015-04-09, closing the long position
# 2015-04-10, SELL EXECUTED, 117.07
# 2015-07-16, Predict long for 2015-07-17
# 2015-07-17, BUY EXECUTED, 134.52
# 2015-07-21, closing the long position
# 2015-07-22, SELL EXECUTED, 138.26
# 2015-08-06, Predict long for 2015-08-07
# 2015-08-07, BUY EXECUTED, 128.60
# 2015-08-11, closing the long position
# 2015-08-12, SELL EXECUTED, 131.03
# 2015-08-12, Predict long for 2015-08-13
# 2015-08-13, BUY EXECUTED, 130.30
# 2015-08-17, closing the long position
# 2015-08-18, SELL EXECUTED, 130.20
# 2015-10-20, Predict long for 2015-10-21
# 2015-10-21, BUY EXECUTED, 115.92
# 2015-10-23, closing the long position
# 2015-10-26, SELL EXECUTED, 123.65
# 2015-11-04, Predict long for 2015-11-05
# 2015-11-05, BUY EXECUTED, 120.46
# 2015-11-09, closing the long position
# 2015-11-10, SELL EXECUTED, 113.77
# 2015-11-10, Predict long for 2015-11-11
# 2015-11-11, BUY EXECUTED, 112.21
# 2015-11-13, closing the long position
# 2015-11-16, SELL EXECUTED, 110.14
# 2015-11-27, Predict long for 2015-11-30
# 2015-11-30, BUY EXECUTED, 109.45
# 2015-12-02, closing the long position
# 2015-12-03, SELL EXECUTED, 106.55
# 2015-12-17, Predict long for 2015-12-18
# 2015-12-18, BUY EXECUTED, 110.14
# 2015-12-22, closing the long position
# 2015-12-23, SELL EXECUTED, 122.07
# 2016-01-06, Predict long for 2016-01-07
# 2016-01-07, BUY EXECUTED, 111.89
# 2016-01-11, closing the long position
# 2016-01-12, SELL EXECUTED, 106.85
# 2016-01-12, Predict long for 2016-01-13
# 2016-01-13, BUY EXECUTED, 100.67
# 2016-01-15, closing the long position
# 2016-01-19, SELL EXECUTED, 102.99
# 2016-01-19, Predict long for 2016-01-20
# 2016-01-20, BUY EXECUTED, 107.49
# 2016-01-22, closing the long position
# 2016-01-25, SELL EXECUTED, 106.70
# 2016-01-26, Predict long for 2016-01-27
# 2016-01-27, BUY EXECUTED, 102.31
# 2016-01-29, closing the long position
# 2016-02-01, SELL EXECUTED, 100.80
# 2016-02-11, Predict long for 2016-02-12
# 2016-02-12, BUY EXECUTED, 102.45
# 2016-02-17, closing the long position
# 2016-02-18, SELL EXECUTED, 103.52
# 2016-02-18, Predict long for 2016-02-19
# 2016-02-19, BUY EXECUTED, 102.61
# 2016-02-23, closing the long position
# 2016-02-24, SELL EXECUTED, 102.08
# 2016-02-24, Predict long for 2016-02-25
# 2016-02-25, BUY EXECUTED, 102.35
# 2016-02-29, closing the long position
# 2016-03-01, SELL EXECUTED, 105.00
# 2016-03-01, Predict long for 2016-03-02
# 2016-03-02, BUY EXECUTED, 104.73
# 2016-03-04, closing the long position
# 2016-03-07, SELL EXECUTED, 104.25
# 2016-03-07, Predict long for 2016-03-08
# 2016-03-08, BUY EXECUTED, 102.62
# 2016-03-10, closing the long position
# 2016-03-11, SELL EXECUTED, 101.85
# 2016-03-11, Predict long for 2016-03-14
# 2016-03-14, BUY EXECUTED, 99.99
# 2016-03-16, closing the long position
# 2016-03-17, SELL EXECUTED, 96.69
# 2016-03-23, Predict long for 2016-03-24
# 2016-03-24, BUY EXECUTED, 100.54
# 2016-03-29, closing the long position
# 2016-03-30, SELL EXECUTED, 98.80
# 2016-03-30, Predict long for 2016-03-31
# 2016-03-31, BUY EXECUTED, 100.09
# 2016-04-04, closing the long position
# 2016-04-05, SELL EXECUTED, 102.12
# 2016-04-07, Predict long for 2016-04-08
# 2016-04-08, BUY EXECUTED, 106.26
# 2016-04-12, closing the long position
# 2016-04-13, SELL EXECUTED, 107.60
# 2016-04-13, Predict long for 2016-04-14
# 2016-04-14, BUY EXECUTED, 106.99
# 2016-04-18, closing the long position
# 2016-04-19, SELL EXECUTED, 106.53
# 2016-04-19, Predict long for 2016-04-20
# 2016-04-20, BUY EXECUTED, 106.73
# 2016-04-22, closing the long position
# 2016-04-25, SELL EXECUTED, 110.57
# 2016-04-26, Predict long for 2016-04-27
# 2016-04-27, BUY EXECUTED, 106.15
# 2016-04-29, closing the long position
# 2016-05-02, SELL EXECUTED, 104.97
# 2016-05-03, Predict long for 2016-05-04
# 2016-05-04, BUY EXECUTED, 100.90
# 2016-05-06, closing the long position
# 2016-05-09, SELL EXECUTED, 102.41
# 2016-05-10, Predict long for 2016-05-11
# 2016-05-11, BUY EXECUTED, 100.25
# 2016-05-13, closing the long position
# 2016-05-16, SELL EXECUTED, 101.57
# 2016-05-16, Predict long for 2016-05-17
# 2016-05-17, BUY EXECUTED, 100.68
# 2016-05-19, closing the long position
# 2016-05-20, SELL EXECUTED, 101.46
# 2016-06-10, Predict long for 2016-06-13
# 2016-06-13, BUY EXECUTED, 101.61
# 2016-06-15, closing the long position
# 2016-06-16, SELL EXECUTED, 100.23
# 2016-06-20, Predict long for 2016-06-21
# 2016-06-21, BUY EXECUTED, 96.86
# 2016-06-23, closing the long position
# 2016-06-24, SELL EXECUTED, 96.29
# 2016-06-24, Predict long for 2016-06-27
# 2016-06-27, BUY EXECUTED, 94.85
# 2016-06-29, closing the long position
# 2016-06-30, SELL EXECUTED, 98.63
# 2016-08-30, Predict long for 2016-08-31
# 2016-08-31, BUY EXECUTED, 106.74
# 2016-09-02, closing the long position
# 2016-09-06, SELL EXECUTED, 106.71
# 2016-09-28, Predict long for 2016-09-29
# 2016-09-29, BUY EXECUTED, 102.77
# 2016-10-03, closing the long position
# 2016-10-04, SELL EXECUTED, 104.67
# 2016-10-12, Predict long for 2016-10-13
# 2016-10-13, BUY EXECUTED, 100.63
# 2016-10-17, closing the long position
# 2016-10-18, SELL EXECUTED, 100.06
# 2016-10-18, Predict long for 2016-10-19
# 2016-10-19, BUY EXECUTED, 100.02
# 2016-10-21, closing the long position
# 2016-10-24, SELL EXECUTED, 98.07
# 2016-10-24, Predict long for 2016-10-25
# 2016-10-25, BUY EXECUTED, 97.63
# 2016-10-27, closing the long position
# 2016-10-28, SELL EXECUTED, 103.90
# 2016-11-10, Predict long for 2016-11-11
# 2016-11-11, BUY EXECUTED, 119.45
# 2016-11-15, closing the long position
# 2016-11-16, SELL EXECUTED, 119.69
# 2016-12-27, 'the label [2016-12-28] is not in the [index]'
# 2016-12-28, 'the label [2016-12-29] is not in the [index]'
# 2016-12-29, 'the label [2016-12-30] is not in the [index]'
# 2016-12-30, array index out of range
# Final Portfolio Value: 118030.21

# %%
pf.create_simple_tear_sheet(returns=returns, 
                          positions=positions, 
                          transactions=transactions)
# Out:
# Entire data start date: 2013-01-02
# Entire data end date: 2016-12-30
# Backtest months: 48
#                     Backtest
# Annual return           4.2%
# Cumulative returns     18.0%
# Annual volatility       6.6%
# Sharpe ratio            0.66
# Calmar ratio            0.83
# Stability               0.91
# Max drawdown           -5.1%
# Omega ratio             1.31
# Sortino ratio           1.05
# Skew                    1.80
# Kurtosis               33.04
# Tail ratio              1.98
# Daily value at risk    -0.8%
# Gross leverage          0.08
# Daily turnover          2.7%
# Alpha                   0.03
# Beta                    0.13
