# %%
from dataloader import DataLoader, DataTransformer
from model import Model
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import backtrader as bt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
tickers = ['SPY']
from_date = datetime(2000, 1, 1)
to_date = datetime(2016, 12, 31)
entry_percentage = 0.65

# %%
loader = DataLoader(tickers, from_date=from_date, to_date=to_date)
loader.reload_all()

# %%
transformer = DataTransformer(loader)
transformer.transform()

# %%
model = Model(transformer)
model.build_model_data()
model.build_neural_net()

# %%
datetime(2016, 12, 31).strftime('%Y-%m-%d')
# Out:
# '2016-12-31'

# %%
model.predict_one('SPY', '2010-10-18')[0]
# Out:
# array([ 0.55760902,  0.44239092], dtype=float32)

# %%
class TestStrategy(bt.Strategy):

    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        self.dataclose = self.datas[0].close
        self.order = None
        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')
        
        self.prev_order = self.order
        self.order = None

    def next(self):
        #self.log('Close, %.2f' % self.dataclose[0])
        
        if self.order:
            return
        
        if not self.position:
            try:
                prediction = model.predict_one('SPY', self.datas[0].datetime.date(0).isoformat())[0]
                if prediction[0] > entry_percentage:
                    self.order = self.buy()
                elif prediction[1] > entry_percentage:
                    self.order = self.sell()
            except Exception as e:
                self.log(e)
        else:
            if len(self) >= (self.bar_executed + 5):
                if self.prev_order.isbuy():
                    self.order = self.sell()
                else:
                    self.order = self.buy()

# %%
cerebro = bt.Cerebro()
cerebro.addstrategy(TestStrategy)

data = bt.feeds.YahooFinanceData(
    dataname='SPY',
    fromdate=datetime(2000, 1, 1),
    todate=datetime(2016, 12, 31),
    reverse=False)

cerebro.adddata(data)
cerebro.broker.setcash(100000.0)
cerebro.broker.setcommission(commission=0.001)
cerebro.addsizer(bt.sizers.PercentSizer, percents=3)

cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')

print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
results = cerebro.run()
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

strat = results[0]
pyfoliozer = strat.analyzers.getbyname('pyfolio')
returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()
# Out:
# Starting Portfolio Value: 100000.00
# 2000-01-03, 'the label [2000-01-03] is not in the [index]'
# 2000-01-04, 'the label [2000-01-04] is not in the [index]'
# 2000-01-05, 'the label [2000-01-05] is not in the [index]'
# 2000-01-06, 'the label [2000-01-06] is not in the [index]'
# 2000-01-07, 'the label [2000-01-07] is not in the [index]'
# 2000-01-10, 'the label [2000-01-10] is not in the [index]'
# 2000-01-11, 'the label [2000-01-11] is not in the [index]'
# 2000-01-12, 'the label [2000-01-12] is not in the [index]'
# 2000-01-13, 'the label [2000-01-13] is not in the [index]'
# 2000-01-14, 'the label [2000-01-14] is not in the [index]'
# 2000-01-18, 'the label [2000-01-18] is not in the [index]'
# 2000-01-19, 'the label [2000-01-19] is not in the [index]'
# 2000-01-20, 'the label [2000-01-20] is not in the [index]'
# 2000-01-21, 'the label [2000-01-21] is not in the [index]'
# 2000-01-24, 'the label [2000-01-24] is not in the [index]'
# 2000-01-25, 'the label [2000-01-25] is not in the [index]'
# 2000-01-26, 'the label [2000-01-26] is not in the [index]'
# 2000-01-27, 'the label [2000-01-27] is not in the [index]'
# 2000-01-28, 'the label [2000-01-28] is not in the [index]'
# 2000-01-31, 'the label [2000-01-31] is not in the [index]'
# 2000-02-01, 'the label [2000-02-01] is not in the [index]'
# 2000-02-02, 'the label [2000-02-02] is not in the [index]'
# 2000-02-03, 'the label [2000-02-03] is not in the [index]'
# 2000-02-04, 'the label [2000-02-04] is not in the [index]'
# 2000-02-07, 'the label [2000-02-07] is not in the [index]'
# 2000-02-08, 'the label [2000-02-08] is not in the [index]'
# 2000-02-09, 'the label [2000-02-09] is not in the [index]'
# 2000-02-10, 'the label [2000-02-10] is not in the [index]'
# 2000-02-11, 'the label [2000-02-11] is not in the [index]'
# 2000-03-15, BUY EXECUTED, 136.88
# 2000-03-23, SELL EXECUTED, 149.16
# 2000-03-24, SELL EXECUTED, 152.88
# 2000-04-03, BUY EXECUTED, 150.12
# 2000-04-19, SELL EXECUTED, 144.50
# 2000-04-28, BUY EXECUTED, 147.00
# 2000-05-24, BUY EXECUTED, 138.00
# 2000-06-02, SELL EXECUTED, 148.94
# 2000-07-06, BUY EXECUTED, 144.94
# 2000-07-14, SELL EXECUTED, 150.44
# 2000-07-31, BUY EXECUTED, 142.94
# 2000-08-08, SELL EXECUTED, 147.50
# 2000-08-28, BUY EXECUTED, 151.25
# 2000-09-06, SELL EXECUTED, 151.19
# 2000-11-10, BUY EXECUTED, 139.00
# 2000-11-20, SELL EXECUTED, 135.75
# 2000-12-21, BUY EXECUTED, 126.00
# 2001-01-02, SELL EXECUTED, 132.00
# 2001-03-07, BUY EXECUTED, 126.90
# 2001-03-15, SELL EXECUTED, 118.45
# 2001-03-23, BUY EXECUTED, 113.25
# 2001-04-02, SELL EXECUTED, 116.30
# 2001-04-06, BUY EXECUTED, 113.99
# 2001-04-17, SELL EXECUTED, 117.31
# 2001-04-20, SELL EXECUTED, 124.90
# 2001-04-30, BUY EXECUTED, 126.45
# 2001-05-10, BUY EXECUTED, 127.26
# 2001-05-18, SELL EXECUTED, 129.09
# 2001-05-25, SELL EXECUTED, 129.65
# 2001-06-05, BUY EXECUTED, 127.49
# 2001-07-12, BUY EXECUTED, 119.50
# 2001-07-20, SELL EXECUTED, 121.15
# 2001-07-23, BUY EXECUTED, 121.80
# 2001-07-31, SELL EXECUTED, 121.00
# 2001-08-07, BUY EXECUTED, 120.27
# 2001-08-15, SELL EXECUTED, 119.23
# 2001-08-20, BUY EXECUTED, 116.80
# 2001-08-28, SELL EXECUTED, 118.28
# 2001-09-28, BUY EXECUTED, 102.98
# 2001-10-08, SELL EXECUTED, 106.27
# 2001-10-19, BUY EXECUTED, 107.00
# 2001-10-29, SELL EXECUTED, 110.16
# 2001-10-31, BUY EXECUTED, 106.90
# 2001-11-08, SELL EXECUTED, 112.87
# 2001-11-13, BUY EXECUTED, 113.44
# 2001-11-21, SELL EXECUTED, 114.50
# 2001-11-29, BUY EXECUTED, 113.66
# 2001-12-07, SELL EXECUTED, 116.90
# 2001-12-28, BUY EXECUTED, 116.29
# 2002-01-08, SELL EXECUTED, 116.79
# 2002-01-09, BUY EXECUTED, 116.68
# 2002-01-17, SELL EXECUTED, 113.76
# 2002-01-23, BUY EXECUTED, 112.63
# 2002-01-31, SELL EXECUTED, 112.15
# 2002-02-20, BUY EXECUTED, 109.05
# 2002-02-28, SELL EXECUTED, 111.83
# 2002-03-14, BUY EXECUTED, 116.04
# 2002-03-22, SELL EXECUTED, 115.50
# 2002-05-07, BUY EXECUTED, 106.10
# 2002-05-15, SELL EXECUTED, 109.50
# 2002-06-24, BUY EXECUTED, 98.61
# 2002-07-02, SELL EXECUTED, 96.86
# 2002-07-08, SELL EXECUTED, 98.98
# 2002-07-16, BUY EXECUTED, 91.12
# 2002-07-25, BUY EXECUTED, 84.27
# 2002-08-02, SELL EXECUTED, 88.50
# 2002-08-08, BUY EXECUTED, 88.42
# 2002-08-16, SELL EXECUTED, 92.82
# 2002-09-04, BUY EXECUTED, 88.61
# 2002-09-12, SELL EXECUTED, 90.75
# 2002-09-27, BUY EXECUTED, 85.00
# 2002-10-07, SELL EXECUTED, 80.06
# 2002-10-08, BUY EXECUTED, 79.81
# 2002-10-16, SELL EXECUTED, 87.41
# 2002-10-18, BUY EXECUTED, 87.65
# 2002-10-28, SELL EXECUTED, 91.15
# 2002-10-30, BUY EXECUTED, 88.68
# 2002-11-07, SELL EXECUTED, 92.02
# 2002-11-08, BUY EXECUTED, 90.53
# 2002-11-18, SELL EXECUTED, 92.15
# 2002-11-19, BUY EXECUTED, 90.02
# 2002-11-27, SELL EXECUTED, 92.52
# 2002-12-10, BUY EXECUTED, 90.02
# 2002-12-18, SELL EXECUTED, 90.32
# 2003-01-28, BUY EXECUTED, 85.63
# 2003-02-05, SELL EXECUTED, 85.75
# 2003-02-11, BUY EXECUTED, 84.37
# 2003-02-20, SELL EXECUTED, 85.21
# 2003-03-11, BUY EXECUTED, 81.48
# 2003-03-19, SELL EXECUTED, 87.28
# 2003-04-17, BUY EXECUTED, 88.30
# 2003-04-28, SELL EXECUTED, 90.44
# 2003-06-25, BUY EXECUTED, 98.53
# 2003-07-03, SELL EXECUTED, 99.07
# 2003-07-18, BUY EXECUTED, 99.02
# 2003-07-28, SELL EXECUTED, 100.37
# 2003-08-11, BUY EXECUTED, 98.26
# 2003-08-19, SELL EXECUTED, 100.69
# 2003-08-21, BUY EXECUTED, 101.05
# 2003-08-29, SELL EXECUTED, 100.61
# 2003-09-11, BUY EXECUTED, 102.10
# 2003-09-19, SELL EXECUTED, 104.27
# 2003-09-23, BUY EXECUTED, 102.59
# 2003-10-01, SELL EXECUTED, 100.24
# 2003-10-24, BUY EXECUTED, 102.83
# 2003-11-03, SELL EXECUTED, 105.75
# 2003-11-19, BUY EXECUTED, 104.03
# 2003-11-28, SELL EXECUTED, 106.28
# 2003-12-24, BUY EXECUTED, 109.52
# 2004-01-05, SELL EXECUTED, 111.69
# 2004-03-11, BUY EXECUTED, 112.40
# 2004-03-19, SELL EXECUTED, 112.41
# 2004-04-07, BUY EXECUTED, 114.95
# 2004-04-16, SELL EXECUTED, 113.38
# 2004-04-19, BUY EXECUTED, 113.55
# 2004-04-27, SELL EXECUTED, 114.23
# 2004-05-26, BUY EXECUTED, 111.66
# 2004-06-04, SELL EXECUTED, 112.98
# 2004-06-21, BUY EXECUTED, 113.75
# 2004-06-29, SELL EXECUTED, 113.53
# 2004-07-26, BUY EXECUTED, 109.19
# 2004-08-03, SELL EXECUTED, 110.93
# 2004-08-12, BUY EXECUTED, 107.68
# 2004-08-20, SELL EXECUTED, 109.61
# 2004-09-07, BUY EXECUTED, 112.54
# 2004-09-15, SELL EXECUTED, 113.30
# 2004-09-21, BUY EXECUTED, 112.75
# 2004-09-29, SELL EXECUTED, 111.21
# 2004-12-22, BUY EXECUTED, 120.38
# 2004-12-31, SELL EXECUTED, 121.30
# 2005-01-06, BUY EXECUTED, 118.44
# 2005-01-14, SELL EXECUTED, 117.97
# 2005-02-22, BUY EXECUTED, 119.90
# 2005-03-02, SELL EXECUTED, 120.76
# 2005-04-28, BUY EXECUTED, 115.27
# 2005-05-06, SELL EXECUTED, 117.93
# 2005-05-13, BUY EXECUTED, 116.30
# 2005-05-23, SELL EXECUTED, 119.21
# 2005-06-10, BUY EXECUTED, 120.56
# 2005-06-20, SELL EXECUTED, 121.08
# 2005-07-20, BUY EXECUTED, 122.59
# 2005-07-28, SELL EXECUTED, 123.96
# 2005-09-16, BUY EXECUTED, 123.30
# 2005-09-26, SELL EXECUTED, 122.02
# 2005-10-31, BUY EXECUTED, 120.29
# 2005-11-08, SELL EXECUTED, 121.93
# 2006-02-21, BUY EXECUTED, 129.11
# 2006-03-01, SELL EXECUTED, 128.60
# 2006-03-02, BUY EXECUTED, 128.90
# 2006-03-10, SELL EXECUTED, 127.71
# 2006-05-19, BUY EXECUTED, 126.87
# 2006-05-30, SELL EXECUTED, 127.97
# 2006-06-28, BUY EXECUTED, 124.19
# 2006-07-07, SELL EXECUTED, 127.19
# 2006-08-14, BUY EXECUTED, 127.63
# 2006-08-22, SELL EXECUTED, 129.99
# 2006-09-12, BUY EXECUTED, 130.56
# 2006-09-20, SELL EXECUTED, 132.25
# 2007-03-15, BUY EXECUTED, 138.97
# 2007-03-23, SELL EXECUTED, 143.28
# 2007-06-25, BUY EXECUTED, 150.24
# 2007-07-03, SELL EXECUTED, 152.18
# 2007-07-11, BUY EXECUTED, 150.75
# 2007-07-19, SELL EXECUTED, 155.20
# 2007-08-15, BUY EXECUTED, 142.72
# 2007-08-23, SELL EXECUTED, 147.34
# 2007-09-13, BUY EXECUTED, 148.55
# 2007-09-21, SELL EXECUTED, 152.71
# 2007-11-21, BUY EXECUTED, 143.08
# 2007-11-30, SELL EXECUTED, 149.04
# 2007-12-04, BUY EXECUTED, 146.66
# 2007-12-12, SELL EXECUTED, 151.06
# 2008-02-07, BUY EXECUTED, 131.80
# 2008-02-15, SELL EXECUTED, 134.50
# 2008-02-26, SELL EXECUTED, 136.75
# 2008-03-05, BUY EXECUTED, 133.42
# 2008-03-07, BUY EXECUTED, 129.77
# 2008-03-17, SELL EXECUTED, 126.57
# 2008-03-31, BUY EXECUTED, 131.29
# 2008-04-08, SELL EXECUTED, 136.19
# 2008-04-09, SELL EXECUTED, 136.61
# 2008-04-17, BUY EXECUTED, 136.02
# 2008-04-18, BUY EXECUTED, 138.94
# 2008-04-28, SELL EXECUTED, 139.88
# 2008-05-23, BUY EXECUTED, 139.05
# 2008-06-03, SELL EXECUTED, 139.30
# 2008-07-01, BUY EXECUTED, 126.52
# 2008-07-10, SELL EXECUTED, 124.43
# 2008-07-11, BUY EXECUTED, 123.97
# 2008-07-21, SELL EXECUTED, 126.51
# 2008-08-04, BUY EXECUTED, 126.04
# 2008-08-12, SELL EXECUTED, 130.28
# 2008-09-05, BUY EXECUTED, 123.29
# 2008-09-15, SELL EXECUTED, 121.63
# 2008-09-18, BUY EXECUTED, 118.05
# 2008-09-26, SELL EXECUTED, 118.83
# 2008-09-29, SELL EXECUTED, 119.14
# 2008-10-07, BUY EXECUTED, 106.84
# 2008-10-08, BUY EXECUTED, 97.52
# 2008-10-16, SELL EXECUTED, 91.29
# 2008-10-17, SELL EXECUTED, 91.99
# 2008-10-27, BUY EXECUTED, 85.97
# 2008-10-28, BUY EXECUTED, 87.34
# 2008-11-05, SELL EXECUTED, 99.20
# 2008-11-06, SELL EXECUTED, 94.46
# 2008-11-14, BUY EXECUTED, 89.41
# 2008-11-17, SELL EXECUTED, 86.38
# 2008-11-25, BUY EXECUTED, 87.30
# 2008-11-28, SELL EXECUTED, 88.63
# 2008-12-08, BUY EXECUTED, 90.34
# 2008-12-10, BUY EXECUTED, 90.32
# 2008-12-18, SELL EXECUTED, 91.40
# 2008-12-23, BUY EXECUTED, 87.53
# 2009-01-02, SELL EXECUTED, 90.44
# 2009-01-07, SELL EXECUTED, 92.00
# 2009-01-15, BUY EXECUTED, 84.12
# 2009-02-03, BUY EXECUTED, 83.10
# 2009-02-11, SELL EXECUTED, 83.45
# 2009-02-13, SELL EXECUTED, 83.55
# 2009-02-24, BUY EXECUTED, 75.29
# 2009-03-06, BUY EXECUTED, 69.40
# 2009-03-16, SELL EXECUTED, 76.96
# 2009-03-23, BUY EXECUTED, 78.74
# 2009-03-31, SELL EXECUTED, 79.56
# 2009-04-09, BUY EXECUTED, 84.67
# 2009-04-20, SELL EXECUTED, 85.54
# 2009-04-23, BUY EXECUTED, 84.71
# 2009-05-01, SELL EXECUTED, 87.44
# 2009-05-14, BUY EXECUTED, 88.72
# 2009-05-22, SELL EXECUTED, 89.46
# 2009-09-02, BUY EXECUTED, 99.78
# 2009-09-11, SELL EXECUTED, 104.99
# 2009-10-02, BUY EXECUTED, 102.02
# 2009-10-12, SELL EXECUTED, 107.76
# 2009-11-02, BUY EXECUTED, 104.13
# 2009-11-10, SELL EXECUTED, 109.31
# 2009-12-04, BUY EXECUTED, 111.84
# 2009-12-14, SELL EXECUTED, 111.87
# 2010-02-02, SELL EXECUTED, 109.26
# 2010-02-10, BUY EXECUTED, 107.05
# 2010-02-11, BUY EXECUTED, 106.87
# 2010-02-22, SELL EXECUTED, 111.55
# 2010-03-10, BUY EXECUTED, 114.51
# 2010-03-18, SELL EXECUTED, 117.11
# 2010-04-05, BUY EXECUTED, 118.25
# 2010-04-13, SELL EXECUTED, 119.62
# 2010-05-21, BUY EXECUTED, 105.91
# 2010-06-01, SELL EXECUTED, 108.35
# 2010-06-03, SELL EXECUTED, 110.65
# 2010-06-11, BUY EXECUTED, 108.19
# 2010-06-14, BUY EXECUTED, 110.52
# 2010-06-22, SELL EXECUTED, 111.41
# 2010-06-24, SELL EXECUTED, 108.69
# 2010-07-02, BUY EXECUTED, 103.11
# 2010-07-15, SELL EXECUTED, 109.61
# 2010-07-23, BUY EXECUTED, 109.24
# 2010-07-29, BUY EXECUTED, 111.52
# 2010-08-06, SELL EXECUTED, 111.74
# 2010-08-16, BUY EXECUTED, 107.57
# 2010-08-24, SELL EXECUTED, 105.95
# 2010-08-26, BUY EXECUTED, 106.44
# 2010-09-03, SELL EXECUTED, 110.54
# 2010-09-09, BUY EXECUTED, 111.65
# 2010-09-17, SELL EXECUTED, 113.04
# 2010-10-05, BUY EXECUTED, 114.80
# 2010-10-13, SELL EXECUTED, 117.66
# 2010-10-20, BUY EXECUTED, 116.94
# 2010-10-28, SELL EXECUTED, 119.06
# 2010-12-28, BUY EXECUTED, 125.90
# 2011-01-05, SELL EXECUTED, 126.58
# 2011-02-01, BUY EXECUTED, 129.46
# 2011-02-09, SELL EXECUTED, 132.21
# 2011-02-14, BUY EXECUTED, 133.03
# 2011-02-23, SELL EXECUTED, 131.75
# 2011-03-17, BUY EXECUTED, 128.00
# 2011-03-25, SELL EXECUTED, 131.24
# 2011-04-06, SELL EXECUTED, 133.88
# 2011-04-14, BUY EXECUTED, 130.70
# 2011-04-15, BUY EXECUTED, 131.80
# 2011-04-26, SELL EXECUTED, 134.05
# 2011-06-07, BUY EXECUTED, 129.70
# 2011-06-15, SELL EXECUTED, 128.24
# 2011-06-16, BUY EXECUTED, 127.06
# 2011-06-24, SELL EXECUTED, 128.27
# 2011-06-29, BUY EXECUTED, 130.20
# 2011-07-08, SELL EXECUTED, 133.83
# 2011-07-13, BUY EXECUTED, 132.09
# 2011-07-21, SELL EXECUTED, 133.40
# 2011-08-09, BUY EXECUTED, 114.07
# 2011-08-17, SELL EXECUTED, 120.25
# 2011-08-19, BUY EXECUTED, 112.96
# 2011-08-29, SELL EXECUTED, 119.56
# 2011-08-30, SELL EXECUTED, 120.83
# 2011-09-08, BUY EXECUTED, 119.57
# 2011-09-09, BUY EXECUTED, 117.68
# 2011-09-19, SELL EXECUTED, 119.53
# 2011-09-20, SELL EXECUTED, 120.82
# 2011-09-28, BUY EXECUTED, 117.78
# 2011-10-04, BUY EXECUTED, 108.35
# 2011-10-12, SELL EXECUTED, 120.60
# 2011-10-21, BUY EXECUTED, 123.09
# 2011-10-31, SELL EXECUTED, 127.16
# 2011-11-02, BUY EXECUTED, 123.83
# 2011-11-10, SELL EXECUTED, 124.79
# 2011-11-17, SELL EXECUTED, 123.85
# 2011-11-28, BUY EXECUTED, 119.54
# 2011-11-30, BUY EXECUTED, 123.49
# 2011-12-08, SELL EXECUTED, 125.90
# 2011-12-12, SELL EXECUTED, 124.95
# 2011-12-20, BUY EXECUTED, 122.18
# 2012-01-03, BUY EXECUTED, 127.76
# 2012-01-11, SELL EXECUTED, 128.73
# 2012-04-05, BUY EXECUTED, 139.38
# 2012-04-16, SELL EXECUTED, 137.84
# 2012-04-23, BUY EXECUTED, 136.54
# 2012-05-01, SELL EXECUTED, 139.79
# 2012-05-21, BUY EXECUTED, 130.16
# 2012-05-30, SELL EXECUTED, 132.56
# 2012-06-12, BUY EXECUTED, 131.79
# 2012-06-20, SELL EXECUTED, 135.71
# 2012-06-27, BUY EXECUTED, 132.42
# 2012-07-06, SELL EXECUTED, 135.47
# 2012-07-13, BUY EXECUTED, 133.86
# 2012-07-23, SELL EXECUTED, 134.47
# 2012-07-24, BUY EXECUTED, 135.19
# 2012-08-01, SELL EXECUTED, 138.70
# 2012-08-03, BUY EXECUTED, 138.56
# 2012-08-13, SELL EXECUTED, 140.60
# 2012-09-27, BUY EXECUTED, 143.89
# 2012-10-05, SELL EXECUTED, 146.91
# 2012-11-01, BUY EXECUTED, 141.65
# 2012-11-09, SELL EXECUTED, 137.62
# 2012-11-15, BUY EXECUTED, 135.98
# 2012-11-26, SELL EXECUTED, 140.65
# 2012-11-29, BUY EXECUTED, 141.99
# 2012-12-07, SELL EXECUTED, 142.53
# 2012-12-11, BUY EXECUTED, 143.06
# 2012-12-19, SELL EXECUTED, 145.53
# 2012-12-31, BUY EXECUTED, 139.66
# 2013-01-09, SELL EXECUTED, 145.87
# 2013-01-10, BUY EXECUTED, 146.73
# 2013-01-18, SELL EXECUTED, 147.97
# 2013-03-22, BUY EXECUTED, 154.85
# 2013-04-02, SELL EXECUTED, 156.61
# 2013-04-08, BUY EXECUTED, 155.27
# 2013-04-16, SELL EXECUTED, 156.29
# 2013-04-19, BUY EXECUTED, 154.50
# 2013-04-29, SELL EXECUTED, 158.67
# 2013-04-30, BUY EXECUTED, 159.27
# 2013-05-08, SELL EXECUTED, 162.42
# 2013-05-15, BUY EXECUTED, 164.96
# 2013-05-23, SELL EXECUTED, 164.16
# 2013-06-13, BUY EXECUTED, 161.66
# 2013-06-21, SELL EXECUTED, 159.64
# 2013-07-05, BUY EXECUTED, 162.47
# 2013-07-15, SELL EXECUTED, 167.97
# 2013-08-30, BUY EXECUTED, 164.51
# 2013-09-10, SELL EXECUTED, 168.64
# 2013-09-13, BUY EXECUTED, 169.13
# 2013-09-23, SELL EXECUTED, 170.49
# 2013-09-25, BUY EXECUTED, 169.64
# 2013-10-03, SELL EXECUTED, 168.79
# 2013-10-08, BUY EXECUTED, 167.40
# 2013-10-16, SELL EXECUTED, 170.72
# 2013-11-07, BUY EXECUTED, 177.50
# 2013-11-15, SELL EXECUTED, 179.56
# 2014-03-17, BUY EXECUTED, 185.59
# 2014-03-25, SELL EXECUTED, 186.37
# 2014-03-27, BUY EXECUTED, 184.75
# 2014-04-04, SELL EXECUTED, 189.66
# 2014-04-14, BUY EXECUTED, 182.93
# 2014-04-23, SELL EXECUTED, 187.82
# 2014-05-23, BUY EXECUTED, 189.76
# 2014-06-03, SELL EXECUTED, 192.43
# 2014-06-16, BUY EXECUTED, 193.89
# 2014-06-24, SELL EXECUTED, 195.53
# 2014-08-08, BUY EXECUTED, 191.46
# 2014-08-18, SELL EXECUTED, 196.80
# 2014-09-11, BUY EXECUTED, 199.27
# 2014-09-19, SELL EXECUTED, 201.52
# 2014-10-14, BUY EXECUTED, 188.42
# 2014-10-22, SELL EXECUTED, 194.41
# 2014-10-30, BUY EXECUTED, 197.58
# 2014-11-07, SELL EXECUTED, 203.17
# 2014-12-15, BUY EXECUTED, 201.98
# 2014-12-23, SELL EXECUTED, 208.17
# 2015-02-13, BUY EXECUTED, 209.07
# 2015-02-24, SELL EXECUTED, 211.12
# 2015-03-11, BUY EXECUTED, 205.29
# 2015-03-19, SELL EXECUTED, 209.96
# 2015-03-27, BUY EXECUTED, 205.13
# 2015-04-07, SELL EXECUTED, 207.86
# 2015-04-09, BUY EXECUTED, 207.78
# 2015-04-17, SELL EXECUTED, 208.94
# 2015-06-01, BUY EXECUTED, 211.94
# 2015-06-09, SELL EXECUTED, 208.45
# 2015-08-10, BUY EXECUTED, 209.28
# 2015-08-18, SELL EXECUTED, 210.26
# 2015-08-25, BUY EXECUTED, 195.43
# 2015-09-02, SELL EXECUTED, 194.62
# 2015-12-14, BUY EXECUTED, 202.07
# 2015-12-22, SELL EXECUTED, 202.72
# 2016-01-22, BUY EXECUTED, 189.78
# 2016-02-01, SELL EXECUTED, 192.53
# 2016-02-08, BUY EXECUTED, 185.77
# 2016-02-17, SELL EXECUTED, 191.16
# 2016-03-10, BUY EXECUTED, 199.96
# 2016-03-18, SELL EXECUTED, 204.17
# 2016-05-12, BUY EXECUTED, 207.29
# 2016-05-20, SELL EXECUTED, 204.92
# 2016-06-03, BUY EXECUTED, 210.25
# 2016-06-13, SELL EXECUTED, 209.36
# 2016-06-20, BUY EXECUTED, 208.82
# 2016-06-28, SELL EXECUTED, 201.48
# 2016-09-28, BUY EXECUTED, 215.83
# 2016-10-06, SELL EXECUTED, 215.37
# 2016-10-14, BUY EXECUTED, 214.15
# 2016-10-24, SELL EXECUTED, 215.00
# 2016-11-07, BUY EXECUTED, 208.55
# 2016-11-15, SELL EXECUTED, 217.04
# 2016-11-22, BUY EXECUTED, 220.51
# 2016-12-01, SELL EXECUTED, 220.73
# 2016-12-23, 'the label [2016-12-23] is not in the [index]'
# 2016-12-27, 'the label [2016-12-27] is not in the [index]'
# 2016-12-28, 'the label [2016-12-28] is not in the [index]'
# 2016-12-29, 'the label [2016-12-29] is not in the [index]'
# 2016-12-30, 'the label [2016-12-30] is not in the [index]'
# Final Portfolio Value: 113146.11

# %%
import pyfolio as pf
pf.create_full_tear_sheet(
    returns,
    positions=positions,
    transactions=transactions,
    live_start_date='2005-05-01',  # This date is sample specific
    round_trips=True)
# Out:
# c:\programdata\anaconda3\envs\trading3\lib\site-packages\empyrical\utils.py:393: UserWarning: Yahoo Finance read failed: mktime argument out of range, falling back to Google
#   UserWarning)
# Entire data start date: 2001-12-18
# Entire data end date: 2016-12-30
# In-sample months: 40
# Out-of-sample months: 139
#                        All In-sample Out-of-sample
# Annual return         0.7%      0.4%          0.8%
# Cumulative returns   11.3%      1.3%          9.9%
# Annual volatility     3.3%      5.2%          2.5%
# Sharpe ratio          0.23      0.10          0.34
# Calmar ratio          0.36      0.20          0.45
# Stability             0.96      0.67          0.95
# Max drawdown         -2.0%     -2.0%         -1.8%
# Omega ratio           1.10      1.04          1.14
# Sortino ratio         0.34      0.15          0.49
# Skew                  0.09      0.05          0.17
# Kurtosis             14.81      6.83         13.63
# Tail ratio            1.21      0.75          1.15
# Daily value at risk  -0.4%     -0.6%         -0.3%
# Gross leverage        0.01      0.01          0.01
# Daily turnover        0.2%      0.2%          0.2%
# Alpha                 0.01      0.01          0.01
# Beta                 -0.00     -0.00         -0.01
# Worst drawdown periods Net drawdown in %  Peak date Valley date Recovery date  \
# 0                                   2.00 2002-07-12  2002-07-25    2002-11-18
# 1                                   1.82 2008-11-20  2008-12-15    2009-02-17
# 2                                   1.48 2008-04-14  2008-07-15    2008-09-29
# 3                                   1.47 2008-10-06  2008-10-10    2008-11-06
# 4                                   1.41 2008-03-04  2008-03-31    2008-04-09
#
# Worst drawdown periods Duration
# 0                            92
# 1                            64
# 2                           121
# 3                            24
# 4                            27
