# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import talib as tl
from sklearn.decomposition import PCA
from sklearn.grid_search import GridSearchCV
from sklearn.preprocessing import LabelBinarizer, StandardScaler
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# Out:
# C:\DEV\Anaconda3\envs\trading\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\DEV\Anaconda3\envs\trading\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
from utils import read_ami_SPY_data

# %%
train_size = 500
test_size = 100
full_size = train_size + test_size
return_day = 10

rolling_std_dev_size = 40
extreme_multiplier = 1

# %%
data = read_ami_SPY_data()

# %%
oopen = data['Open'].values
high = data['High'].values
low = data['Low'].values
close = data['Close'].values

# %%
features_to_delete = data.columns.tolist()

# %% [markdown]
# # ROC

# %%
for i in [2, 5, 10, 20, 30]:
    data[f'ROC {i}'] = tl.ROC(close, timeperiod=i)

# %%
data['2008-07': '2008-10'][['ROC 2', 'ROC 5', 'ROC 10', 'ROC 20', 'ROC 30']].plot()

# %% [markdown]
# # Deviation from zero-lag exponential MA

# %%
for i in [10, 20, 40]:
    lag = (i-1)/2
    ema_data = 2*data['Close'] - data['Close'].shift(i).fillna(method='bfill')
    data['Deviation EMA ' + str(i)] = data['Close'] - tl.EMA(ema_data.values, timeperiod=i)

# %%
data['2008'][['Deviation EMA 10', 'Deviation EMA 20', 'Deviation EMA 40']].plot()

# %% [markdown]
# # MACD

# %%
for i, j, k in [(14, 20, 12), (12, 16, 9), (3, 5, 2)]:
    macd, macdsignal, macdhist = tl.MACD(close, fastperiod=i, slowperiod=j, signalperiod=k)
    data[f'MACD ({i}, {j}, {k})'] = macd
#     data[f'MACD signal ({i}, {j}, {k})'] = macdsignal
    data[f'MACD hist ({i}, {j}, {k})'] = macdhist

# %%
data['2008'][['MACD (14, 20, 12)', 'MACD (12, 16, 9)', 'MACD (3, 5, 2)']].plot()

# %%
# data['2008'][['MACD signal (12, 16, 9)', 'MACD signal (3, 5, 2)']].plot()

# %%
data['2008'][['MACD hist (14, 20, 12)', 'MACD hist (12, 16, 9)', 'MACD hist (3, 5, 2)']].plot()

# %% [markdown]
# # RSI

# %%
for i in [5, 10, 14, 20]:
    data[f'RSI {i}'] = tl.RSI(close, timeperiod=i)

# %%
data['2008'][['RSI 5', 'RSI 10', 'RSI 14', 'RSI 20']].plot()

# %% [markdown]
# # SMA differences

# %%
for i, j in [(5, 10), (10, 20), (20, 40)]:
    data[f'SMA ({i}, {j}) diff'] = tl.SMA(close, timeperiod=i) - tl.SMA(close, timeperiod=j)

# %%
data['2008'][['SMA (5, 10) diff', 'SMA (10, 20) diff', 'SMA (20, 40) diff']].plot()

# %% [markdown]
# # ADX

# %%
data['ADX 20'] = tl.ADX(high, low, close, timeperiod=20)
data['ADX 14'] = tl.ADX(high, low, close, timeperiod=14)
data['ADX 7'] = tl.ADX(high, low, close, timeperiod=7)

# %%
data['2005'][['ADX 7', 'ADX 14', 'ADX 20']].plot()

# %% [markdown]
# # CCI

# %%
# data['CCI 14'] = tl.CCI(high, low, close, timeperiod=14)

# %%
# data['2008']['CCI 14'].plot()

# %% [markdown]
# # STD deviation 20

# %%
data['Std dev 10'] = tl.STDDEV(close, timeperiod=10)
data['Std dev 20'] = tl.STDDEV(close, timeperiod=20)

# %%
data['2008'][['Std dev 10', 'Std dev 20']].plot()

# %% [markdown]
# # Y target value

# %%
data['Return'] = data['Close'].pct_change(return_day).shift(-return_day)*100
data['Return scaled'] = data['Return'] / (data['Return'].rolling(return_day).std().fillna(1.0))

# %%
data.dropna(inplace=True)
data.drop(columns=features_to_delete, inplace=True)
data.head()
# Out:
#                ROC 2     ROC 5    ROC 10    ROC 20    ROC 30  \
# Date
# 1999-05-05 -0.644864 -0.415512 -0.046339  1.243877  6.835067
# 1999-05-06  0.175178 -0.267523 -1.595153 -0.637330  5.577426
# 1999-05-07  0.139082  1.313321 -0.598251  0.092678  4.247104
# 1999-05-10  0.256597 -1.001861 -1.658642 -1.455773  4.484667
# 1999-05-11  0.509259  1.448598 -1.138434  0.184587  3.454888
#
#             Deviation EMA 10  Deviation EMA 20  Deviation EMA 40  \
# Date
# 1999-05-05         -1.793634         -2.853139         -0.432770
# 1999-05-06         -1.750246         -3.248888         -1.433450
# 1999-05-07         -0.453265         -2.032408         -0.610786
# 1999-05-10         -0.508662         -2.257764         -1.461731
# 1999-05-11          0.980149         -0.836615         -0.315329
#
#             MACD (14, 20, 12)  MACD hist (14, 20, 12)      ...        \
# Date                                                       ...
# 1999-05-05           0.403900               -0.055075      ...
# 1999-05-06           0.351419               -0.091009      ...
# 1999-05-07           0.344498               -0.082864      ...
# 1999-05-10           0.309100               -0.100067      ...
# 1999-05-11           0.329205               -0.067660      ...
#
#             SMA (5, 10) diff  SMA (10, 20) diff  SMA (20, 40) diff     ADX 20  \
# Date
# 1999-05-05          -0.93437            0.93594           2.150785  20.440722
# 1999-05-06          -0.78906            0.76172           1.987895  19.525417
# 1999-05-07          -0.35781            0.67422           1.884770  18.655876
# 1999-05-10          -0.40313            0.54688           1.661723  17.785037
# 1999-05-11           0.14062            0.37813           1.562503  17.270934
#
#                ADX 14      ADX 7  Std dev 10  Std dev 20    Return  \
# Date
# 1999-05-05  20.489020  27.166137    1.199364    1.942356  0.069504
# 1999-05-06  19.845702  28.433563    1.221660    1.940844  0.081651
# 1999-05-07  19.248335  29.519928    1.197413    1.942808 -1.226889
# 1999-05-10  18.298311  28.103513    1.084316    1.888977 -2.384535
# 1999-05-11  17.280123  24.967837    0.789305    1.897725 -4.928604
#
#             Return scaled
# Date
# 1999-05-05       0.055983
# 1999-05-06       0.071297
# 1999-05-07      -1.027132
# 1999-05-10      -1.814070
# 1999-05-11      -2.476156
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Features

# %%
feature_names = data.drop(['Return', 'Return scaled'], axis=1).columns

# %% [markdown]
# # Train and test Random Forest

# %%
def to_class(y_vec):
    y_extreme = extreme_multiplier * y_vec.rolling(rolling_std_dev_size).std().fillna(method='bfill')
    
    pos = y_vec > y_extreme
    neg = y_vec < -1*y_extreme

    y_vec[:] = 'Neutral'
    y_vec[pos] = 'Pos'
    y_vec[neg] = 'Neg'
    return y_vec

# %%
def make_X_y(df):
    X = df.drop(['Return', 'Return scaled'], axis=1)
    y = df['Return'].copy()
    ret = y.copy()
    y = to_class(y)
    return X, y, ret

# %%
def split_X_y(X, y, ret):
    X_train = X.iloc[:train_size]
    X_test = X.iloc[train_size:]
    y_train = y.iloc[:train_size]
    y_test = y.iloc[train_size:]
    ret = ret.iloc[train_size:]
    
    last_q4 = int(train_size/4)
    last_q8 = int(train_size/8)
    last_q16 = int(train_size/16)
    X_train = pd.concat([X_train, X_train[-last_q4:], X_train[-last_q8:], X_train[-last_q16:]], ignore_index=True)
    y_train = pd.concat([y_train, y_train[-last_q4:], y_train[-last_q8:], y_train[-last_q16:]], ignore_index=True)
    return X_train, X_test, y_train, y_test, ret

# %%
def print_labels_distrib(y_train, y_test):
    def distrib_print(vec):
        print('---\nDistribution:\n' + str(vec.value_counts()))
        
    distrib_print(y_train)
    distrib_print(y_test)

# %%
from sklearn.metrics import make_scorer
def custom_loss(y_true, y_pred):
    bad = ((y_true == 'Pos') & (y_pred == 'Neg')) | ((y_true == 'Neg') & (y_pred == 'Pos'))
    bad_sum = -20*np.sum(bad)
    avg = ((y_true == 'Neutral') & (y_pred == 'Pos')) | ((y_true == 'Neutral') & (y_pred == 'Neg'))
    avg_sum = -2*np.sum(avg)
    good = ((y_true == 'Pos') & (y_pred == 'Pos')) | ((y_true == 'Neg') & (y_pred == 'Neg'))
    good_sum = 7*np.sum(good)
    return bad_sum + good_sum
scorer = make_scorer(custom_loss, greater_is_better=True)

# %%
def calculate_returns(ret, y_pred):
    longs = np.nansum(ret[y_pred == 'Pos'])
    shorts = np.nansum(-1*ret[y_pred == 'Neg'])
    ret_sum = longs + shorts
    print(f'{longs} [long] + {shorts} [short] = {ret_sum}')
    return ret_sum

# %%
def print_results(y_test, y_pred):
    print('---\nClassification report\n', classification_report(y_test, y_pred))
    print('---\nConfusion matrix\n', str(confusion_matrix(y_test, y_pred)))

# %% [markdown]
# ## Train and Test

# %%
def train_and_test(df):
    X, y, ret = make_X_y(df)
    X_train, X_test, y_train, y_test, ret = split_X_y(X, y, ret)
    print_labels_distrib(y_train, y_test)
    
    params = {'n_estimators': [50, 100],
#               'max_depth': [3,4,None],
              'max_features': [3,4],
              'min_samples_split': [2,3,4],
              'min_samples_leaf': [2,3]}
    grid = GridSearchCV(estimator=RandomForestClassifier(n_jobs=8, class_weight='balanced_subsample', max_depth=None),
                        param_grid=params, 
                        scoring=scorer,
                        cv=4)
    
    grid.fit(X_train, y_train)
    best_estimator = grid.best_estimator_
    best_params = grid.best_params_
    
    y_pred = best_estimator.predict(X_test)
    print_results(y_test, y_pred)
    acc = accuracy_score(y_test, y_pred)
    ret_sum = calculate_returns(ret, y_pred)
    
    param = {
        'accuracy':acc,
        'date': df.iloc[0].name,
        'best_params': best_params,
        'features': best_estimator.feature_importances_,
        'ret_sum': ret_sum
    }
    test_params.append(param)

# %%
test_params = []

for i in range(0, len(data)-full_size, test_size):
    sub_data = data.iloc[i:i+full_size]
    from_date, to_date = sub_data.index[0], sub_data.index[-1]
    sep = 100*'='
    print(f'{sep}\nFrom {from_date} to {to_date}')
    train_and_test(sub_data)
# Out:
# ====================================================================================================
# From 1999-05-05 00:00:00 to 2001-09-24 00:00:00
# ---
# Distribution:
# Neutral    415
# Neg        178
# Pos        125
# Name: Return, dtype: int64
# ---
# Distribution:
# Neutral    57
# Neg        36
# Pos         7
# Name: Return, dtype: int64
# ---
# Classification report
#               precision    recall  f1-score   support
#
#         Neg       0.73      0.31      0.43        36
#     Neutral       0.60      0.77      0.68        57
#         Pos       0.25      0.43      0.32         7
#
# avg / total       0.63      0.58      0.56       100
#
# ---
# Confusion matrix
#  [[11 25  0]
#  [ 4 44  9]
#  [ 0  4  3]]
# 23.478798402609 [long] + 43.97968199693644 [short] = 67.45848039954544
# ====================================================================================================
# From 1999-09-27 00:00:00 to 2002-02-15 00:00:00
# ---
# Distribution:
# Neutral    403
# Neg        208
# Pos        107
# Name: Return, dtype: int64
# ---
# Distribution:
# Neutral    76
# Neg        14
# Pos        10
# Name: Return, dtype: int64
# ---
# Classification report
#               precision    recall  f1-score   support
#
#         Neg       0.30      0.79      0.43        14
#     Neutral       0.81      0.62      0.70        76
#         Pos       0.20      0.10      0.13        10
#
# avg / total       0.68      0.59      0.61       100
#
# ---
# Confusion matrix
#  [[11  3  0]
#  [25 47  4]
#  [ 1  8  1]]
# 16.37424182617404 [long] + 13.273134646511895 [short] = 29.647376472685934
# ====================================================================================================
# From 2000-02-17 00:00:00 to 2002-07-11 00:00:00
# ---
# Distribution:
# Neutral    456
# Neg        179
# Pos         83
# Name: Return, dtype: int64
# ---
# Distribution:
# Neg        45
# Neutral    42
# Pos        13
# Name: Return, dtype: int64
# ---
# Classification report
#               precision    recall  f1-score   support
#
#         Neg       0.56      0.44      0.49        45
#     Neutral       0.48      0.71      0.58        42
#         Pos       0.00      0.00      0.00        13
#
# avg / total       0.45      0.50      0.46       100
#
# ---
# Confusion matrix
#  [[20 23  2]
#  [12 30  0]
#  [ 4  9  0]]
# -7.872978196348567 [long] + 90.18005137413462 [short] = 82.30707317778605
# ====================================================================================================
# From 2000-07-12 00:00:00 to 2002-12-02 00:00:00
# ---
# Distribution:
# Neutral    369
# Neg        275
# Pos         74
# Name: Return, dtype: int64
# ---
# Distribution:
# Neutral    73
# Pos        16
# Neg        11
# Name: Return, dtype: int64
# ---
# Classification report
#               precision    recall  f1-score   support
#
#         Neg       0.46      0.55      0.50        11
#     Neutral       0.86      0.86      0.86        73
#         Pos       0.50      0.44      0.47        16
#
# avg / total       0.76      0.76      0.76       100
#
# ---
# Confusion matrix
#  [[ 6  5  0]
#  [ 3 63  7]
#  [ 4  5  7]]
# 69.89098568104849 [long] + -2.196434487070407 [short] = 67.69455119397809
# ====================================================================================================
# From 2000-12-01 00:00:00 to 2003-04-28 00:00:00
# ---
# Distribution:
# Neutral    453
# Neg        176
# Pos         89
# Name: Return, dtype: int64
# ---
# Distribution:
# Neutral    59
# Pos        26
# Neg        15
# Name: Return, dtype: int64
# C:\DEV\Anaconda3\envs\trading\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ---
# Classification report
#               precision    recall  f1-score   support
#
#         Neg       0.13      0.27      0.17        15
#     Neutral       0.61      0.71      0.66        59
#         Pos       0.00      0.00      0.00        26
#
# avg / total       0.38      0.46      0.41       100
#
# ---
# Confusion matrix
#  [[ 4 11  0]
#  [17 42  0]
#  [10 16  0]]
# 0.0 [long] + -32.63893577422696 [short] = -32.63893577422696
# ====================================================================================================
# From 2001-04-27 00:00:00 to 2003-09-18 00:00:00
# ---
# Distribution:
# Neutral    443
# Neg        142
# Pos        133
# Name: Return, dtype: int64
# ---
# Distribution:
# Neutral    61
# Pos        31
# Neg         8
# Name: Return, dtype: int64
# ---
# Classification report
#               precision    recall  f1-score   support
#
#         Neg       0.04      0.12      0.06         8
#     Neutral       0.62      0.74      0.68        61
#         Pos       1.00      0.06      0.12        31
#
# avg / total       0.69      0.48      0.46       100
#
# ---
# Confusion matrix
#  [[ 1  7  0]
#  [16 45  0]
#  [ 9 20  2]]
# 6.6046507397054866 [long] + -27.404734322261348 [short] = -20.80008358255586
# ====================================================================================================
# From 2001-09-25 00:00:00 to 2004-02-11 00:00:00
# ---
# Distribution:
# Neutral    436
# Pos        171
# Neg        111
# Name: Return, dtype: int64
# ---
# Distribution:
# Pos        49
# Neutral    48
# Neg         3
# Name: Return, dtype: int64
# ---
# Classification report
#               precision    recall  f1-score   support
#
#         Neg       0.00      0.00      0.00         3
#     Neutral       0.53      0.81      0.64        48
#         Pos       0.60      0.24      0.35        49
#
# avg / total       0.55      0.51      0.48       100
#
# ---
# Confusion matrix
#  [[ 0  2  1]
#  [ 2 39  7]
#  [ 5 32 12]]
# 29.011105226719245 [long] + -11.14348219170438 [short] = 17.867623035014866
# ====================================================================================================
# From 2002-02-19 00:00:00 to 2004-07-07 00:00:00
# ---
# Distribution:
# Neutral    379
# Pos        246
# Neg         93
# Name: Return, dtype: int64
# ---
# Distribution:
# Neutral    62
# Neg        24
# Pos        14
# Name: Return, dtype: int64
# ---
# Classification report
#               precision    recall  f1-score   support
#
#         Neg       0.04      0.04      0.04        24
#     Neutral       0.67      0.47      0.55        62
#         Pos       0.00      0.00      0.00        14
#
# avg / total       0.43      0.30      0.35       100
#
# ---
# Confusion matrix
#  [[ 1  9 14]
#  [18 29 15]
#  [ 9  5  0]]
# -49.10763334180522 [long] + -31.97003274824769 [short] = -81.0776660900529
# ====================================================================================================
# From 2002-07-12 00:00:00 to 2004-11-26 00:00:00
# ---
# Distribution:
# Neutral    439
# Pos        172
# Neg        107
# Name: Return, dtype: int64
# ---
# Distribution:
# Neutral    55
# Pos        26
# Neg        19
# Name: Return, dtype: int64
# ---
# Classification report
#               precision    recall  f1-score   support
#
#         Neg       0.17      0.05      0.08        19
#     Neutral       0.58      0.82      0.68        55
#         Pos       0.35      0.23      0.28        26
#
# avg / total       0.44      0.52      0.46       100
#
# ---
# Confusion matrix
#  [[ 1 12  6]
#  [ 5 45  5]
#  [ 0 20  6]]
# 4.416708696284953 [long] + 0.06383230805760975 [short] = 4.480541004342562
# ====================================================================================================
# From 2002-12-03 00:00:00 to 2005-04-21 00:00:00
# ---
# Distribution:
# Neutral    418
# Pos        199
# Neg        101
# Name: Return, dtype: int64
# ---
# Distribution:
# Neutral    61
# Neg        26
# Pos        13
# Name: Return, dtype: int64
# ---
# Classification report
#               precision    recall  f1-score   support
#
#         Neg       0.30      0.12      0.17        26
#     Neutral       0.60      0.62      0.61        61
#         Pos       0.07      0.15      0.10        13
#
# avg / total       0.46      0.43      0.43       100
#
# ---
# Confusion matrix
#  [[ 3 16  7]
#  [ 5 38 18]
#  [ 2  9  2]]
# -11.786548287031584 [long] + 2.627716754161191 [short] = -9.158831532870392
# ====================================================================================================
# From 2003-04-29 00:00:00 to 2005-09-13 00:00:00
# ---
# Distribution:
# Neutral    424
# Pos        162
# Neg        132
# Name: Return, dtype: int64
# ---
# Distribution:
# Neutral    61
# Pos        22
# Neg        17
# Name: Return, dtype: int64

# %%
indexes = [d['date'] for d in test_params]

# %% [markdown]
# ### Random Forest parameters with Accuracy and Returns

# %%
params = pd.DataFrame([d['best_params'] for d in test_params], index=indexes)
params['Sum of return'] = [d['ret_sum'] for d in test_params]
params['Accuracy'] = [d['accuracy'] for d in test_params]

# %%
params.sort_values('Sum of return', ascending=False)

# %%
params.describe()

# %%
params['Accuracy'].plot()

# %%
params['Sum of return'].plot()

# %% [markdown]
# ### Feature importances

# %%
features = pd.DataFrame([d['features'] for d in test_params], index=indexes, columns=feature_names)

# %%
features.idxmax(axis=1).value_counts()

# %%
plt.figure(figsize=(15,8))
sns.heatmap(features)

# %%
plt.figure(figsize=(10,20))
sns.violinplot(data=features, orient='h')
