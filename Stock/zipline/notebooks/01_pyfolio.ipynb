# %%
# %matplotlib inline
import pyfolio as pf

# %%
stock_rets = pf.utils.get_symbol_rets('FB')

# %%
pf.create_full_tear_sheet(stock_rets, live_start_date='2015-12-1')
# Out:
# Entire data start date: 2012-05-21
# Entire data end date: 2017-09-25
# In-sample months: 42
# Out-of-sample months: 21
#                         All In-sample Out-of-sample
# Annual return         31.2%     32.9%         27.8%
# Cumulative returns   326.0%    172.7%         56.2%
# Annual volatility     37.8%     43.2%         24.1%
# Sharpe ratio           0.90      0.87          1.14
# Calmar ratio           0.58      0.61          2.03
# Stability              0.92      0.89          0.89
# Max drawdown         -53.6%    -53.6%        -13.7%
# Omega ratio            1.19      1.18          1.25
# Sortino ratio          1.45      1.39          1.83
# Skew                   1.90      1.73          2.03
# Kurtosis              23.85     19.44         24.47
# Tail ratio             1.11      1.04          0.96
# Daily value at risk   -4.6%     -5.3%         -2.9%
# Alpha                  0.18      0.21          0.13
# Beta                   1.04      1.01          1.12
# Worst drawdown periods Net drawdown in %  Peak date Valley date Recovery date  \
# 0                                  47.90 2012-05-21  2012-09-04    2013-07-25
# 1                                  22.06 2014-03-10  2014-04-28    2014-07-24
# 2                                  17.34 2013-10-18  2013-11-25    2013-12-17
# 3                                  16.57 2015-07-21  2015-08-24    2015-10-19
# 4                                  13.68 2016-10-24  2016-12-30    2017-02-08
#
# Worst drawdown periods Duration
# 0                           309
# 1                            99
# 2                            43
# 3                            65
# 4                            78
# /usr/local/lib/python3.4/site-packages/numpy/lib/function_base.py:4269: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# Stress Events   mean     min    max
# EZB IR Event   0.23%  -9.06%  7.72%
# Apr14          0.12%  -5.21%  7.25%
# Oct14         -0.20%  -6.08%  4.57%
# Fall2015      -0.12%  -4.98%  5.05%
# Recovery      -0.15% -11.69% 19.13%
# New Normal     0.17%  -6.93% 29.61%

# %%
pf.create_returns_tear_sheet(stock_rets, live_start_date='2015-12-1')
