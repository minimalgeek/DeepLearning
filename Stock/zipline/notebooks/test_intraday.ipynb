# %% [markdown]
# # Converting

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import os
from data_loader import *

# %%
data = get_minute_data_and_cache('MSFT', 50, 50)

# %%
len(data)
# Out:
# 49

# %%
data.index
# Out:
# DatetimeIndex(['2017-07-21 20:00:00', '2017-07-21 20:03:00',
#                '2017-07-21 20:04:00', '2017-07-21 20:05:00',
#                '2017-07-21 20:06:00', '2017-07-21 20:07:00',
#                '2017-07-21 20:10:00', '2017-07-21 20:11:00',
#                '2017-07-21 20:12:00', '2017-07-21 20:13:00',
#                '2017-07-21 20:14:00', '2017-07-21 20:17:00',
#                '2017-07-21 20:18:00', '2017-07-21 20:19:00',
#                '2017-07-21 20:20:00', '2017-07-21 20:21:00',
#                '2017-07-21 20:24:00', '2017-07-21 20:25:00',
#                '2017-07-21 20:26:00', '2017-07-21 20:27:00',
#                '2017-07-21 20:28:00', '2017-07-21 20:31:00',
#                '2017-07-21 20:32:00', '2017-07-21 20:33:00',
#                '2017-07-21 20:34:00', '2017-07-21 20:35:00',
#                '2017-07-21 20:38:00', '2017-07-21 20:39:00',
#                '2017-07-21 20:40:00', '2017-07-21 20:41:00',
# ...

# %%
data.index
# Out:
# DatetimeIndex(['2017-07-21 20:00:00', '2017-07-21 20:03:00',
#                '2017-07-21 20:04:00', '2017-07-21 20:05:00',
#                '2017-07-21 20:06:00', '2017-07-21 20:07:00',
#                '2017-07-21 20:10:00', '2017-07-21 20:11:00',
#                '2017-07-21 20:12:00', '2017-07-21 20:13:00',
#                '2017-07-21 20:14:00', '2017-07-21 20:17:00',
#                '2017-07-21 20:18:00', '2017-07-21 20:19:00',
#                '2017-07-21 20:20:00', '2017-07-21 20:21:00',
#                '2017-07-21 20:24:00', '2017-07-21 20:25:00',
#                '2017-07-21 20:26:00', '2017-07-21 20:27:00',
#                '2017-07-21 20:28:00', '2017-07-21 20:31:00',
#                '2017-07-21 20:32:00', '2017-07-21 20:33:00',
#                '2017-07-21 20:34:00', '2017-07-21 20:35:00',
#                '2017-07-21 20:38:00', '2017-07-21 20:39:00',
#                '2017-07-21 20:40:00', '2017-07-21 20:41:00',
# ...
