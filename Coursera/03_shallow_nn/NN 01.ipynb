# %%
import numpy as np

# %%
A = np.random.randn(4,3)
B = np.sum(A, axis = 1, keepdims = True)

# %%
B.shape
# Out:
# (4, 1)

# %%
B
# Out:
# array([[-1.50281265],
#        [-3.77662435],
#        [ 2.91305076],
#        [-0.69006178]])
